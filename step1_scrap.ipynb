# %%
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import time

API_KEY = "7b1e25c715e2b1fd047c1f76e5bf407f"
BASE_URL = "https://api.themoviedb.org/3"

def fetch_genres(api_key):
    try:
        response = requests.get(
            f"{BASE_URL}/genre/movie/list",
            params={"api_key": api_key, "language": "en-US"},
        )
        response.raise_for_status()
        data = response.json()
        return {genre["id"]: genre["name"] for genre in data.get("genres", [])}
    except requests.exceptions.RequestException as e:
        print(f"Error fetching genres: {e}")
        return {}

def fetch_movies(api_key, category="top_rated"):
    all_movies = []
    page = 1

    while True:
        try:
            response = requests.get(
                f"{BASE_URL}/movie/{category}",
                params={"api_key": api_key, "language": "en-US", "page": page},
            )
            response.raise_for_status()
            data = response.json()

            # If there are no more movies, break the loop
            if not data.get("results"):
                break

            # Append movie results
            all_movies.extend(data.get("results", []))
            print(f"Page {page} of {category} fetched successfully.")
            page += 1

            # Rate limiting (optional)
            time.sleep(0.5)

        except requests.exceptions.RequestException as e:
            print(f"Error fetching page {page}: {e}")
            break

    return all_movies

def fetch_movie_details(api_key, movie_id):
    try:
        response = requests.get(
            f"{BASE_URL}/movie/{movie_id}",
            params={"api_key": api_key, "language": "en-US"},
        )
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching details for movie ID {movie_id}: {e}")
        return None

def fetch_movie_credits(api_key, movie_id):
    try:
        response = requests.get(
            f"{BASE_URL}/movie/{movie_id}/credits",
            params={"api_key": api_key},
        )
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching credits for movie ID {movie_id}: {e}")
        return None

def enrich_movie_data(movie, genre_map):
    movie_id = movie.get("id")
    details = fetch_movie_details(API_KEY, movie_id)
    credits = fetch_movie_credits(API_KEY, movie_id)

    if details:
        genre_names = [genre_map.get(genre_id) for genre_id in movie.get("genre_ids", []) if genre_map.get(genre_id)]
        
        enriched_movie = {
            "id": movie.get("id"),
            "title": movie.get("title"),
            "release_date": movie.get("release_date"),
            "vote_average": movie.get("vote_average"),
            "overview": movie.get("overview"),
            "poster_path": f"https://image.tmdb.org/t/p/w500{movie.get('poster_path')}" if movie.get('poster_path') else None,
            "original_language": movie.get("original_language"),
            "genre_names": ", ".join(genre_names),  # List of genre names
            "popularity": movie.get("popularity"),
            "vote_count": movie.get("vote_count"),
            "backdrop_path": f"https://image.tmdb.org/t/p/w500{movie.get('backdrop_path')}" if movie.get('backdrop_path') else None,
            "original_title": details.get("original_title"),
            "adult": details.get("adult"),
            "video": details.get("video"),
            "production_companies": ", ".join([company["name"] for company in details.get("production_companies", [])]),
            "production_countries": ", ".join([country["name"] for country in details.get("production_countries", [])]),
            "runtime": details.get("runtime"),
            "spoken_languages": ", ".join([lang["name"] for lang in details.get("spoken_languages", [])]),
            "budget": details.get("budget"),
            "revenue": details.get("revenue"),
            "status": details.get("status"),
            "tagline": details.get("tagline"),
            "homepage": details.get("homepage"),
            "imdb_id": details.get("imdb_id"),
            # Limit to the first 3 cast members
            "cast": ", ".join([cast_member["name"] for cast_member in credits.get("cast", [])[:3]]) if credits else None,
            # Only take the first crew member (director)
            "crew": ", ".join([crew_member["name"] for crew_member in credits.get("crew", []) if crew_member["job"] == "Director"][:1]) if credits else None,
        }
        return enriched_movie
    return None

genre_map = fetch_genres(API_KEY)

movies = fetch_movies(API_KEY, category="top_rated")
print(f"Fetched {len(movies)} movies.")

with ThreadPoolExecutor(max_workers=10) as executor:
    enriched_movies = list(executor.map(lambda movie: enrich_movie_data(movie, genre_map), movies))

enriched_movies = [movie for movie in enriched_movies if movie is not None]

print(f"Enriched data for {len(enriched_movies)} movies.")

def save_movies_to_csv(movies, filename="tmdb_movies.csv"):
    if not movies:
        print("No movies to save.")
        return
    df = pd.DataFrame(movies)
    df.to_csv(filename, index=False, encoding="utf-8")
    print(f"Movies saved to '{filename}'.")

save_movies_to_csv(enriched_movies)
# Out:
# Page 1 of top_rated fetched successfully.
# Page 2 of top_rated fetched successfully.
# Page 3 of top_rated fetched successfully.
# Page 4 of top_rated fetched successfully.
# Page 5 of top_rated fetched successfully.
# Page 6 of top_rated fetched successfully.
# Page 7 of top_rated fetched successfully.
# Page 8 of top_rated fetched successfully.
# Page 9 of top_rated fetched successfully.
# Page 10 of top_rated fetched successfully.
# Page 11 of top_rated fetched successfully.
# Page 12 of top_rated fetched successfully.
# Page 13 of top_rated fetched successfully.
# Page 14 of top_rated fetched successfully.
# Page 15 of top_rated fetched successfully.
# Page 16 of top_rated fetched successfully.
# Page 17 of top_rated fetched successfully.
# Page 18 of top_rated fetched successfully.
# Page 19 of top_rated fetched successfully.
# Page 20 of top_rated fetched successfully.
# Page 21 of top_rated fetched successfully.
# Page 22 of top_rated fetched successfully.
# Page 23 of top_rated fetched successfully.
# Page 24 of top_rated fetched successfully.
# Page 25 of top_rated fetched successfully.
# Page 26 of top_rated fetched successfully.
# Page 27 of top_rated fetched successfully.
# Page 28 of top_rated fetched successfully.
# Page 29 of top_rated fetched successfully.
# Page 30 of top_rated fetched successfully.
# Page 31 of top_rated fetched successfully.
# Page 32 of top_rated fetched successfully.
# Page 33 of top_rated fetched successfully.
# Page 34 of top_rated fetched successfully.
# Page 35 of top_rated fetched successfully.
# Page 36 of top_rated fetched successfully.
# Page 37 of top_rated fetched successfully.
# Page 38 of top_rated fetched successfully.
# Page 39 of top_rated fetched successfully.
# Page 40 of top_rated fetched successfully.
# Page 41 of top_rated fetched successfully.
# Page 42 of top_rated fetched successfully.
# Page 43 of top_rated fetched successfully.
# Page 44 of top_rated fetched successfully.
# Page 45 of top_rated fetched successfully.
# Page 46 of top_rated fetched successfully.
# Page 47 of top_rated fetched successfully.
# Page 48 of top_rated fetched successfully.
# Page 49 of top_rated fetched successfully.
# Page 50 of top_rated fetched successfully.
# Page 51 of top_rated fetched successfully.
# Page 52 of top_rated fetched successfully.
# Page 53 of top_rated fetched successfully.
# Page 54 of top_rated fetched successfully.
# Page 55 of top_rated fetched successfully.
# Page 56 of top_rated fetched successfully.
# Page 57 of top_rated fetched successfully.
# Page 58 of top_rated fetched successfully.
# Page 59 of top_rated fetched successfully.
# Page 60 of top_rated fetched successfully.
# Page 61 of top_rated fetched successfully.
# Page 62 of top_rated fetched successfully.
# Page 63 of top_rated fetched successfully.
# Page 64 of top_rated fetched successfully.
# Page 65 of top_rated fetched successfully.
# Page 66 of top_rated fetched successfully.
# Page 67 of top_rated fetched successfully.
# Page 68 of top_rated fetched successfully.
# Page 69 of top_rated fetched successfully.
# Page 70 of top_rated fetched successfully.
# Page 71 of top_rated fetched successfully.
# Page 72 of top_rated fetched successfully.
# Page 73 of top_rated fetched successfully.
# Page 74 of top_rated fetched successfully.
# Page 75 of top_rated fetched successfully.
# Page 76 of top_rated fetched successfully.
# Page 77 of top_rated fetched successfully.
# Page 78 of top_rated fetched successfully.
# Page 79 of top_rated fetched successfully.
# Page 80 of top_rated fetched successfully.
# Page 81 of top_rated fetched successfully.
# Page 82 of top_rated fetched successfully.
# Page 83 of top_rated fetched successfully.
# Page 84 of top_rated fetched successfully.
# Page 85 of top_rated fetched successfully.
# Page 86 of top_rated fetched successfully.
# Page 87 of top_rated fetched successfully.
# Page 88 of top_rated fetched successfully.
# Page 89 of top_rated fetched successfully.
# Page 90 of top_rated fetched successfully.
# Page 91 of top_rated fetched successfully.
# Page 92 of top_rated fetched successfully.
# Page 93 of top_rated fetched successfully.
# Page 94 of top_rated fetched successfully.
# Page 95 of top_rated fetched successfully.
# Page 96 of top_rated fetched successfully.
# Page 97 of top_rated fetched successfully.
# Page 98 of top_rated fetched successfully.
# Page 99 of top_rated fetched successfully.
# Page 100 of top_rated fetched successfully.
# Page 101 of top_rated fetched successfully.
# Page 102 of top_rated fetched successfully.
# Page 103 of top_rated fetched successfully.
# Page 104 of top_rated fetched successfully.
# Page 105 of top_rated fetched successfully.
# Page 106 of top_rated fetched successfully.
# Page 107 of top_rated fetched successfully.
# Page 108 of top_rated fetched successfully.
# Page 109 of top_rated fetched successfully.
# Page 110 of top_rated fetched successfully.
# Page 111 of top_rated fetched successfully.
# Page 112 of top_rated fetched successfully.
# Page 113 of top_rated fetched successfully.
# Page 114 of top_rated fetched successfully.
# Page 115 of top_rated fetched successfully.
# Page 116 of top_rated fetched successfully.
# Page 117 of top_rated fetched successfully.
# Page 118 of top_rated fetched successfully.
# Page 119 of top_rated fetched successfully.
# Page 120 of top_rated fetched successfully.
# Page 121 of top_rated fetched successfully.
# Page 122 of top_rated fetched successfully.
# Page 123 of top_rated fetched successfully.
# Page 124 of top_rated fetched successfully.
# Page 125 of top_rated fetched successfully.
# Page 126 of top_rated fetched successfully.
# Page 127 of top_rated fetched successfully.
# Page 128 of top_rated fetched successfully.
# Page 129 of top_rated fetched successfully.
# Page 130 of top_rated fetched successfully.
# Page 131 of top_rated fetched successfully.
# Page 132 of top_rated fetched successfully.
# Page 133 of top_rated fetched successfully.
# Page 134 of top_rated fetched successfully.
# Page 135 of top_rated fetched successfully.
# Page 136 of top_rated fetched successfully.
# Page 137 of top_rated fetched successfully.
# Page 138 of top_rated fetched successfully.
# Page 139 of top_rated fetched successfully.
# Page 140 of top_rated fetched successfully.
# Page 141 of top_rated fetched successfully.
# Page 142 of top_rated fetched successfully.
# Page 143 of top_rated fetched successfully.
# Page 144 of top_rated fetched successfully.
# Page 145 of top_rated fetched successfully.
# Page 146 of top_rated fetched successfully.
# Page 147 of top_rated fetched successfully.
# Page 148 of top_rated fetched successfully.
# Page 149 of top_rated fetched successfully.
# Page 150 of top_rated fetched successfully.
# Page 151 of top_rated fetched successfully.
# Page 152 of top_rated fetched successfully.
# Page 153 of top_rated fetched successfully.
# Page 154 of top_rated fetched successfully.
# Page 155 of top_rated fetched successfully.
# Page 156 of top_rated fetched successfully.
# Page 157 of top_rated fetched successfully.
# Page 158 of top_rated fetched successfully.
# Page 159 of top_rated fetched successfully.
# Page 160 of top_rated fetched successfully.
# Page 161 of top_rated fetched successfully.
# Page 162 of top_rated fetched successfully.
# Page 163 of top_rated fetched successfully.
# Page 164 of top_rated fetched successfully.
# Page 165 of top_rated fetched successfully.
# Page 166 of top_rated fetched successfully.
# Page 167 of top_rated fetched successfully.
# Page 168 of top_rated fetched successfully.
# Page 169 of top_rated fetched successfully.
# Page 170 of top_rated fetched successfully.
# Page 171 of top_rated fetched successfully.
# Page 172 of top_rated fetched successfully.
# Page 173 of top_rated fetched successfully.
# Page 174 of top_rated fetched successfully.
# Page 175 of top_rated fetched successfully.
# Page 176 of top_rated fetched successfully.
# Page 177 of top_rated fetched successfully.
# Page 178 of top_rated fetched successfully.
# Page 179 of top_rated fetched successfully.
# Page 180 of top_rated fetched successfully.
# Page 181 of top_rated fetched successfully.
# Page 182 of top_rated fetched successfully.
# Page 183 of top_rated fetched successfully.
# Page 184 of top_rated fetched successfully.
# Page 185 of top_rated fetched successfully.
# Page 186 of top_rated fetched successfully.
# Page 187 of top_rated fetched successfully.
# Page 188 of top_rated fetched successfully.
# Page 189 of top_rated fetched successfully.
# Page 190 of top_rated fetched successfully.
# Page 191 of top_rated fetched successfully.
# Page 192 of top_rated fetched successfully.
# Page 193 of top_rated fetched successfully.
# Page 194 of top_rated fetched successfully.
# Page 195 of top_rated fetched successfully.
# Page 196 of top_rated fetched successfully.
# Page 197 of top_rated fetched successfully.
# Page 198 of top_rated fetched successfully.
# Page 199 of top_rated fetched successfully.
# Page 200 of top_rated fetched successfully.
# Page 201 of top_rated fetched successfully.
# Page 202 of top_rated fetched successfully.
# Page 203 of top_rated fetched successfully.
# Page 204 of top_rated fetched successfully.
# Page 205 of top_rated fetched successfully.
# Page 206 of top_rated fetched successfully.
# Page 207 of top_rated fetched successfully.
# Page 208 of top_rated fetched successfully.
# Page 209 of top_rated fetched successfully.
# Page 210 of top_rated fetched successfully.
# Page 211 of top_rated fetched successfully.
# Page 212 of top_rated fetched successfully.
# Page 213 of top_rated fetched successfully.
# Page 214 of top_rated fetched successfully.
# Page 215 of top_rated fetched successfully.
# Page 216 of top_rated fetched successfully.
# Page 217 of top_rated fetched successfully.
# Page 218 of top_rated fetched successfully.
# Page 219 of top_rated fetched successfully.
# Page 220 of top_rated fetched successfully.
# Page 221 of top_rated fetched successfully.
# Page 222 of top_rated fetched successfully.
# Page 223 of top_rated fetched successfully.
# Page 224 of top_rated fetched successfully.
# Page 225 of top_rated fetched successfully.
# Page 226 of top_rated fetched successfully.
# Page 227 of top_rated fetched successfully.
# Page 228 of top_rated fetched successfully.
# Page 229 of top_rated fetched successfully.
# Page 230 of top_rated fetched successfully.
# Page 231 of top_rated fetched successfully.
# Page 232 of top_rated fetched successfully.
# Page 233 of top_rated fetched successfully.
# Page 234 of top_rated fetched successfully.
# Page 235 of top_rated fetched successfully.
# Page 236 of top_rated fetched successfully.
# Page 237 of top_rated fetched successfully.
# Page 238 of top_rated fetched successfully.
# Page 239 of top_rated fetched successfully.
# Page 240 of top_rated fetched successfully.
# Page 241 of top_rated fetched successfully.
# Page 242 of top_rated fetched successfully.
# Page 243 of top_rated fetched successfully.
# Page 244 of top_rated fetched successfully.
# Page 245 of top_rated fetched successfully.
# Page 246 of top_rated fetched successfully.
# Page 247 of top_rated fetched successfully.
# Page 248 of top_rated fetched successfully.
# Page 249 of top_rated fetched successfully.
# Page 250 of top_rated fetched successfully.
# Page 251 of top_rated fetched successfully.
# Page 252 of top_rated fetched successfully.
# Page 253 of top_rated fetched successfully.
# Page 254 of top_rated fetched successfully.
# Page 255 of top_rated fetched successfully.
# Page 256 of top_rated fetched successfully.
# Page 257 of top_rated fetched successfully.
# Page 258 of top_rated fetched successfully.
# Page 259 of top_rated fetched successfully.
# Page 260 of top_rated fetched successfully.
# Page 261 of top_rated fetched successfully.
# Page 262 of top_rated fetched successfully.
# Page 263 of top_rated fetched successfully.
# Page 264 of top_rated fetched successfully.
# Page 265 of top_rated fetched successfully.
# Page 266 of top_rated fetched successfully.
# Page 267 of top_rated fetched successfully.
# Page 268 of top_rated fetched successfully.
# Page 269 of top_rated fetched successfully.
# Page 270 of top_rated fetched successfully.
# Page 271 of top_rated fetched successfully.
# Page 272 of top_rated fetched successfully.
# Page 273 of top_rated fetched successfully.
# Page 274 of top_rated fetched successfully.
# Page 275 of top_rated fetched successfully.
# Page 276 of top_rated fetched successfully.
# Page 277 of top_rated fetched successfully.
# Page 278 of top_rated fetched successfully.
# Page 279 of top_rated fetched successfully.
# Page 280 of top_rated fetched successfully.
# Page 281 of top_rated fetched successfully.
# Page 282 of top_rated fetched successfully.
# Page 283 of top_rated fetched successfully.
# Page 284 of top_rated fetched successfully.
# Page 285 of top_rated fetched successfully.
# Page 286 of top_rated fetched successfully.
# Page 287 of top_rated fetched successfully.
# Page 288 of top_rated fetched successfully.
# Page 289 of top_rated fetched successfully.
# Page 290 of top_rated fetched successfully.
# Page 291 of top_rated fetched successfully.
# Page 292 of top_rated fetched successfully.
# Page 293 of top_rated fetched successfully.
# Page 294 of top_rated fetched successfully.
# Page 295 of top_rated fetched successfully.
# Page 296 of top_rated fetched successfully.
# Page 297 of top_rated fetched successfully.
# Page 298 of top_rated fetched successfully.
# Page 299 of top_rated fetched successfully.
# Page 300 of top_rated fetched successfully.
# Page 301 of top_rated fetched successfully.
# Page 302 of top_rated fetched successfully.
# Page 303 of top_rated fetched successfully.
# Page 304 of top_rated fetched successfully.
# Page 305 of top_rated fetched successfully.
# Page 306 of top_rated fetched successfully.
# Page 307 of top_rated fetched successfully.
# Page 308 of top_rated fetched successfully.
# Page 309 of top_rated fetched successfully.
# Page 310 of top_rated fetched successfully.
# Page 311 of top_rated fetched successfully.
# Page 312 of top_rated fetched successfully.
# Page 313 of top_rated fetched successfully.
# Page 314 of top_rated fetched successfully.
# Page 315 of top_rated fetched successfully.
# Page 316 of top_rated fetched successfully.
# Page 317 of top_rated fetched successfully.
# Page 318 of top_rated fetched successfully.
# Page 319 of top_rated fetched successfully.
# Page 320 of top_rated fetched successfully.
# Page 321 of top_rated fetched successfully.
# Page 322 of top_rated fetched successfully.
# Page 323 of top_rated fetched successfully.
# Page 324 of top_rated fetched successfully.
# Page 325 of top_rated fetched successfully.
# Page 326 of top_rated fetched successfully.
# Page 327 of top_rated fetched successfully.
# Page 328 of top_rated fetched successfully.
# Page 329 of top_rated fetched successfully.
# Page 330 of top_rated fetched successfully.
# Page 331 of top_rated fetched successfully.
# Page 332 of top_rated fetched successfully.
# Page 333 of top_rated fetched successfully.
# Page 334 of top_rated fetched successfully.
# Page 335 of top_rated fetched successfully.
# Page 336 of top_rated fetched successfully.
# Page 337 of top_rated fetched successfully.
# Page 338 of top_rated fetched successfully.
# Page 339 of top_rated fetched successfully.
# Page 340 of top_rated fetched successfully.
# Page 341 of top_rated fetched successfully.
# Page 342 of top_rated fetched successfully.
# Page 343 of top_rated fetched successfully.
# Page 344 of top_rated fetched successfully.
# Page 345 of top_rated fetched successfully.
# Page 346 of top_rated fetched successfully.
# Page 347 of top_rated fetched successfully.
# Page 348 of top_rated fetched successfully.
# Page 349 of top_rated fetched successfully.
# Page 350 of top_rated fetched successfully.
# Page 351 of top_rated fetched successfully.
# Page 352 of top_rated fetched successfully.
# Page 353 of top_rated fetched successfully.
# Page 354 of top_rated fetched successfully.
# Page 355 of top_rated fetched successfully.
# Page 356 of top_rated fetched successfully.
# Page 357 of top_rated fetched successfully.
# Page 358 of top_rated fetched successfully.
# Page 359 of top_rated fetched successfully.
# Page 360 of top_rated fetched successfully.
# Page 361 of top_rated fetched successfully.
# Page 362 of top_rated fetched successfully.
# Page 363 of top_rated fetched successfully.
# Page 364 of top_rated fetched successfully.
# Page 365 of top_rated fetched successfully.
# Page 366 of top_rated fetched successfully.
# Page 367 of top_rated fetched successfully.
# Page 368 of top_rated fetched successfully.
# Page 369 of top_rated fetched successfully.
# Page 370 of top_rated fetched successfully.
# Page 371 of top_rated fetched successfully.
# Page 372 of top_rated fetched successfully.
# Page 373 of top_rated fetched successfully.
# Page 374 of top_rated fetched successfully.
# Page 375 of top_rated fetched successfully.
# Page 376 of top_rated fetched successfully.
# Page 377 of top_rated fetched successfully.
# Page 378 of top_rated fetched successfully.
# Page 379 of top_rated fetched successfully.
# Page 380 of top_rated fetched successfully.
# Page 381 of top_rated fetched successfully.
# Page 382 of top_rated fetched successfully.
# Page 383 of top_rated fetched successfully.
# Page 384 of top_rated fetched successfully.
# Page 385 of top_rated fetched successfully.
# Page 386 of top_rated fetched successfully.
# Page 387 of top_rated fetched successfully.
# Page 388 of top_rated fetched successfully.
# Page 389 of top_rated fetched successfully.
# Page 390 of top_rated fetched successfully.
# Page 391 of top_rated fetched successfully.
# Page 392 of top_rated fetched successfully.
# Page 393 of top_rated fetched successfully.
# Page 394 of top_rated fetched successfully.
# Page 395 of top_rated fetched successfully.
# Page 396 of top_rated fetched successfully.
# Page 397 of top_rated fetched successfully.
# Page 398 of top_rated fetched successfully.
# Page 399 of top_rated fetched successfully.
# Page 400 of top_rated fetched successfully.
# Page 401 of top_rated fetched successfully.
# Page 402 of top_rated fetched successfully.
# Page 403 of top_rated fetched successfully.
# Page 404 of top_rated fetched successfully.
# Page 405 of top_rated fetched successfully.
# Page 406 of top_rated fetched successfully.
# Page 407 of top_rated fetched successfully.
# Page 408 of top_rated fetched successfully.
# Page 409 of top_rated fetched successfully.
# Page 410 of top_rated fetched successfully.
# Page 411 of top_rated fetched successfully.
# Page 412 of top_rated fetched successfully.
# Page 413 of top_rated fetched successfully.
# Page 414 of top_rated fetched successfully.
# Page 415 of top_rated fetched successfully.
# Page 416 of top_rated fetched successfully.
# Page 417 of top_rated fetched successfully.
# Page 418 of top_rated fetched successfully.
# Page 419 of top_rated fetched successfully.
# Page 420 of top_rated fetched successfully.
# Page 421 of top_rated fetched successfully.
# Page 422 of top_rated fetched successfully.
# Page 423 of top_rated fetched successfully.
# Page 424 of top_rated fetched successfully.
# Page 425 of top_rated fetched successfully.
# Page 426 of top_rated fetched successfully.
# Page 427 of top_rated fetched successfully.
# Page 428 of top_rated fetched successfully.
# Page 429 of top_rated fetched successfully.
# Page 430 of top_rated fetched successfully.
# Page 431 of top_rated fetched successfully.
# Page 432 of top_rated fetched successfully.
# Page 433 of top_rated fetched successfully.
# Page 434 of top_rated fetched successfully.
# Page 435 of top_rated fetched successfully.
# Page 436 of top_rated fetched successfully.
# Page 437 of top_rated fetched successfully.
# Page 438 of top_rated fetched successfully.
# Page 439 of top_rated fetched successfully.
# Page 440 of top_rated fetched successfully.
# Page 441 of top_rated fetched successfully.
# Page 442 of top_rated fetched successfully.
# Page 443 of top_rated fetched successfully.
# Page 444 of top_rated fetched successfully.
# Page 445 of top_rated fetched successfully.
# Page 446 of top_rated fetched successfully.
# Page 447 of top_rated fetched successfully.
# Page 448 of top_rated fetched successfully.
# Page 449 of top_rated fetched successfully.
# Page 450 of top_rated fetched successfully.
# Page 451 of top_rated fetched successfully.
# Page 452 of top_rated fetched successfully.
# Page 453 of top_rated fetched successfully.
# Page 454 of top_rated fetched successfully.
# Page 455 of top_rated fetched successfully.
# Page 456 of top_rated fetched successfully.
# Page 457 of top_rated fetched successfully.
# Page 458 of top_rated fetched successfully.
# Page 459 of top_rated fetched successfully.
# Page 460 of top_rated fetched successfully.
# Page 461 of top_rated fetched successfully.
# Page 462 of top_rated fetched successfully.
# Page 463 of top_rated fetched successfully.
# Page 464 of top_rated fetched successfully.
# Page 465 of top_rated fetched successfully.
# Page 466 of top_rated fetched successfully.
# Page 467 of top_rated fetched successfully.
# Page 468 of top_rated fetched successfully.
# Page 469 of top_rated fetched successfully.
# Page 470 of top_rated fetched successfully.
# Page 471 of top_rated fetched successfully.
# Page 472 of top_rated fetched successfully.
# Page 473 of top_rated fetched successfully.
# Page 474 of top_rated fetched successfully.
# Page 475 of top_rated fetched successfully.
# Page 476 of top_rated fetched successfully.
# Page 477 of top_rated fetched successfully.
# Page 478 of top_rated fetched successfully.
# Page 479 of top_rated fetched successfully.
# Page 480 of top_rated fetched successfully.
# Page 481 of top_rated fetched successfully.
# Page 482 of top_rated fetched successfully.
# Page 483 of top_rated fetched successfully.
# Page 484 of top_rated fetched successfully.
# Page 485 of top_rated fetched successfully.
# Page 486 of top_rated fetched successfully.
# Page 487 of top_rated fetched successfully.
# Page 488 of top_rated fetched successfully.
# Page 489 of top_rated fetched successfully.
# Page 490 of top_rated fetched successfully.
# Fetched 9797 movies.
# Error fetching credits for movie ID 9770: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 9061: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 227783: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 10733: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching details for movie ID 14869: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 3603: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 11451: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching details for movie ID 62206: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error fetching credits for movie ID 341392: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 277368: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Error fetching credits for movie ID 47964: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
# Enriched data for 9795 movies.
# Movies saved to 'tmdb_movies.csv'.
